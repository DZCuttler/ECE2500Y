# %%
import copy
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from compressai.entropy_models import EntropyBottleneck
from mnist_cnn import MNIST
from model_splitting import split_model
from lat_acc_test_funcs import eval_accuracy
from HECS import hecs_bottleneck, training_stage1, training_stage2
from itertools import product
# Out:
# /Users/david/miniforge3/envs/venv/lib/python3.10/site-packages/compressai/models/video/google.py:353: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @amp.autocast(enabled=False)

# %%
trainset, validset, testset = MNIST()
trainloader = DataLoader(trainset, batch_size=128, shuffle=True)
validloader = DataLoader(validset, batch_size=128, shuffle=True)
testloader = DataLoader(testset, batch_size=1, shuffle=False)

# %%
model = torch.load('models/MNIST_CNN_Complex.pt', weights_only=False)
head, tail = split_model(model, 10)

# %%
encoder = nn.Sequential(
    nn.Conv2d(1, 32, 3, padding=1),
    nn.ReLU(),
    nn.Conv2d(32, 64, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2, 2), 
    nn.Conv2d(64, 4, 3, padding=1),
)

decoder = nn.Sequential(
    nn.ConvTranspose2d(4, 32, 3, padding=1),
    nn.ReLU(),
    nn.ConvTranspose2d(32, 64, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(2, 2),
)

bottleneck = EntropyBottleneck(4)

student = hecs_bottleneck(encoder, bottleneck, decoder, copy.deepcopy(tail))

# %%
a_values = [0.1, 0.3, 0.5, 0.7, 0.9]
T_values = [1, 2, 4]
beta_values = [0.001, 0.01, 0.1]

results = []
for a, T, beta in product(a_values, T_values, beta_values):
    print(f"\n=== Running a={a}, T={T}, beta={beta} ===")
    training_stage1(model, student, trainloader, epochs=5, a=a, T=T, beta=beta, quiet=True)

    acc = eval_accuracy(student, validloader, quiet=False)
    print(f"Latency: {student.get_avg_inference_time():.4}")
    print(f"Transmission Size: {student.get_avg_transmission_sizes()} bytes")

    results.append((a, T, beta, acc, student.get_avg_inference_time(), student.get_avg_transmission_sizes()))
    student.clear_stats()
# Out:
# === Running a=0.1, T=1, beta=0.001 ===
# Accuracy: 98.74%
# Latency: 0.2396
# Transmission Size: (392000.0, 5045.6) bytes
#
# === Running a=0.1, T=1, beta=0.01 ===
# Accuracy: 95.18%
# Latency: 0.229
# Transmission Size: (392000.0, 2535.2) bytes
#
# === Running a=0.1, T=1, beta=0.1 ===
# Accuracy: 58.84%
# Latency: 0.2365
# Transmission Size: (392000.0, 2000.0) bytes
#
# === Running a=0.1, T=2, beta=0.001 ===
# Accuracy: 98.86%
# Latency: 0.237
# Transmission Size: (392000.0, 6007.0) bytes
#
# === Running a=0.1, T=2, beta=0.01 ===
# Accuracy: 98.60%
# Latency: 0.2329
# Transmission Size: (392000.0, 3017.9) bytes
#
# === Running a=0.1, T=2, beta=0.1 ===
# Accuracy: 94.78%
# Latency: 0.1825
# Transmission Size: (392000.0, 2202.8) bytes
#
# === Running a=0.1, T=4, beta=0.001 ===
# Accuracy: 99.22%
# Latency: 0.1721
# Transmission Size: (392000.0, 8003.6) bytes
#
# === Running a=0.1, T=4, beta=0.01 ===
# Accuracy: 99.02%
# Latency: 0.1927
# Transmission Size: (392000.0, 3879.0) bytes
#
# === Running a=0.1, T=4, beta=0.1 ===
# Accuracy: 98.14%
# Latency: 0.1924
# Transmission Size: (392000.0, 2429.7) bytes
#
# === Running a=0.3, T=1, beta=0.001 ===
# Accuracy: 98.38%
# Latency: 0.1765
# Transmission Size: (392000.0, 2856.6) bytes
#
# === Running a=0.3, T=1, beta=0.01 ===
# Accuracy: 95.86%
# Latency: 0.1912
# Transmission Size: (392000.0, 2214.0) bytes
#
# === Running a=0.3, T=1, beta=0.1 ===
# Accuracy: 80.12%
# Latency: 0.1925
# Transmission Size: (392000.0, 2000.0) bytes
#
# === Running a=0.3, T=2, beta=0.001 ===
# Accuracy: 99.04%
# Latency: 0.2568
# Transmission Size: (392000.0, 3445.9) bytes
#
# === Running a=0.3, T=2, beta=0.01 ===
# Accuracy: 97.14%
# Latency: 0.1935
# Transmission Size: (392000.0, 2375.2) bytes
#
# === Running a=0.3, T=2, beta=0.1 ===
# Accuracy: 92.30%
# Latency: 0.2299
# Transmission Size: (392000.0, 2038.4) bytes
#
# === Running a=0.3, T=4, beta=0.001 ===
# Accuracy: 99.14%
# Latency: 0.1927
# Transmission Size: (392000.0, 4565.5) bytes
#
# === Running a=0.3, T=4, beta=0.01 ===
# Accuracy: 98.74%
# Latency: 0.2282
# Transmission Size: (392000.0, 2780.4) bytes
#
# === Running a=0.3, T=4, beta=0.1 ===
# Accuracy: 96.08%
# Latency: 0.1913
# Transmission Size: (392000.0, 2135.8) bytes
#
# === Running a=0.5, T=1, beta=0.001 ===
# Accuracy: 98.26%
# Latency: 0.1933
# Transmission Size: (392000.0, 2670.5) bytes
#
# === Running a=0.5, T=1, beta=0.01 ===
# Accuracy: 94.74%
# Latency: 0.1917
# Transmission Size: (392000.0, 2075.3) bytes
#
# === Running a=0.5, T=1, beta=0.1 ===
# Accuracy: 69.36%
# Latency: 0.3865
# Transmission Size: (392000.0, 2000.0) bytes
#
# === Running a=0.5, T=2, beta=0.001 ===
# Accuracy: 98.54%
# Latency: 0.4041
# Transmission Size: (392000.0, 2709.7) bytes
#
# === Running a=0.5, T=2, beta=0.01 ===
# Accuracy: 95.62%
# Latency: 0.1924
# Transmission Size: (392000.0, 2186.6) bytes
#
# === Running a=0.5, T=2, beta=0.1 ===
# Accuracy: 84.68%
# Latency: 0.4889
# Transmission Size: (392000.0, 2000.0) bytes
#
# === Running a=0.5, T=4, beta=0.001 ===
# Accuracy: 98.74%
# Latency: 0.1925
# Transmission Size: (392000.0, 3265.8) bytes
#
# === Running a=0.5, T=4, beta=0.01 ===
# Accuracy: 97.54%
# Latency: 0.2167
# Transmission Size: (392000.0, 2394.3) bytes
#
# === Running a=0.5, T=4, beta=0.1 ===
# Accuracy: 94.00%
# Latency: 0.1894
# Transmission Size: (392000.0, 2054.0) bytes
#
# === Running a=0.7, T=1, beta=0.001 ===
# Accuracy: 96.50%
# Latency: 0.1929
# Transmission Size: (392000.0, 2366.8) bytes
#
# === Running a=0.7, T=1, beta=0.01 ===
# Accuracy: 94.54%
# Latency: 0.1916
# Transmission Size: (392000.0, 2050.7) bytes
#
# === Running a=0.7, T=1, beta=0.1 ===
# Accuracy: 22.02%
# Latency: 0.1938
# Transmission Size: (392000.0, 2000.0) bytes
#
# === Running a=0.7, T=2, beta=0.001 ===
# Accuracy: 96.22%
# Latency: 0.413
# Transmission Size: (392000.0, 2453.5) bytes
#
# === Running a=0.7, T=2, beta=0.01 ===
# Accuracy: 95.08%
# Latency: 0.1825
# Transmission Size: (392000.0, 2104.6) bytes
#
# === Running a=0.7, T=2, beta=0.1 ===
# Accuracy: 69.00%
# Latency: 0.1922
# Transmission Size: (392000.0, 2000.0) bytes
#
# === Running a=0.7, T=4, beta=0.001 ===
# Accuracy: 98.08%
# Latency: 0.1929
# Transmission Size: (392000.0, 2786.5) bytes
#
# === Running a=0.7, T=4, beta=0.01 ===
# Accuracy: 96.40%
# Latency: 0.3138
# Transmission Size: (392000.0, 2276.5) bytes
#
# === Running a=0.7, T=4, beta=0.1 ===
# Accuracy: 91.54%
# Latency: 0.4578
# Transmission Size: (392000.0, 2006.9) bytes
#
# === Running a=0.9, T=1, beta=0.001 ===
# Accuracy: 96.28%
# Latency: 0.1917
# Transmission Size: (392000.0, 2344.0) bytes
#
# === Running a=0.9, T=1, beta=0.01 ===
# Accuracy: 93.06%
# Latency: 0.1935
# Transmission Size: (392000.0, 2023.7) bytes
#
# === Running a=0.9, T=1, beta=0.1 ===
# Accuracy: 11.80%
# Latency: 0.1942
# Transmission Size: (392000.0, 2000.0) bytes
#
# === Running a=0.9, T=2, beta=0.001 ===
# Accuracy: 95.88%
# Latency: 0.1916
# Transmission Size: (392000.0, 2555.7) bytes
#
# === Running a=0.9, T=2, beta=0.01 ===
# Accuracy: 83.22%
# Latency: 0.1928
# Transmission Size: (392000.0, 2001.8) bytes
#
# === Running a=0.9, T=2, beta=0.1 ===
# Accuracy: 22.52%
# Latency: 0.2284
# Transmission Size: (392000.0, 2000.0) bytes
#
# === Running a=0.9, T=4, beta=0.001 ===
# Accuracy: 97.18%
# Latency: 0.1952
# Transmission Size: (392000.0, 2687.0) bytes
#
# === Running a=0.9, T=4, beta=0.01 ===
# Accuracy: 82.82%
# Latency: 0.1917
# Transmission Size: (392000.0, 2038.8) bytes
#
# === Running a=0.9, T=4, beta=0.1 ===
# Accuracy: 70.06%
# Latency: 0.1931
# Transmission Size: (392000.0, 2000.0) bytes

# %%
results.filter()
# Out:
# [(0.1, 1, 0.001, 98.74, 0.2395565390586853, (392000.0, 5045.6)),
#  (0.1, 1, 0.01, 95.18, 0.2290206789970398, (392000.0, 2535.2)),
#  (0.1, 1, 0.1, 58.84, 0.2364691376686096, (392000.0, 2000.0)),
#  (0.1, 2, 0.001, 98.86, 0.23698900938034057, (392000.0, 6007.0)),
#  (0.1, 2, 0.01, 98.6, 0.2328951895236969, (392000.0, 3017.9)),
#  (0.1, 2, 0.1, 94.78, 0.18251324892044068, (392000.0, 2202.8)),
#  (0.1, 4, 0.001, 99.22, 0.17210156321525574, (392000.0, 8003.6)),
#  (0.1, 4, 0.01, 99.02, 0.1926710546016693, (392000.0, 3879.0)),
#  (0.1, 4, 0.1, 98.14, 0.19238696098327637, (392000.0, 2429.7)),
#  (0.3, 1, 0.001, 98.38, 0.17650046348571777, (392000.0, 2856.6)),
#  (0.3, 1, 0.01, 95.86, 0.19117312431335448, (392000.0, 2214.0)),
#  (0.3, 1, 0.1, 80.12, 0.19246523976325988, (392000.0, 2000.0)),
#  (0.3, 2, 0.001, 99.04, 0.2567841649055481, (392000.0, 3445.9)),
#  (0.3, 2, 0.01, 97.14, 0.19354044198989867, (392000.0, 2375.2)),
#  (0.3, 2, 0.1, 92.3, 0.22992007732391356, (392000.0, 2038.4)),
#  (0.3, 4, 0.001, 99.14, 0.19272406697273253, (392000.0, 4565.5)),
#  (0.3, 4, 0.01, 98.74, 0.22817450165748596, (392000.0, 2780.4)),
#  (0.3, 4, 0.1, 96.08, 0.19130685329437255, (392000.0, 2135.8)),
#  (0.5, 1, 0.001, 98.26, 0.1933051884174347, (392000.0, 2670.5)),
#  (0.5, 1, 0.01, 94.74, 0.1917216360569, (392000.0, 2075.3)),
#  (0.5, 1, 0.1, 69.36, 0.3865498721599579, (392000.0, 2000.0)),
#  (0.5, 2, 0.001, 98.54, 0.40406508445739747, (392000.0, 2709.7)),
#  (0.5, 2, 0.01, 95.62, 0.1923802375793457, (392000.0, 2186.6)),
#  (0.5, 2, 0.1, 84.68, 0.48888939023017886, (392000.0, 2000.0)),
#  (0.5, 4, 0.001, 98.74, 0.19248526096343993, (392000.0, 3265.8)),
#  (0.5, 4, 0.01, 97.54, 0.21670730113983155, (392000.0, 2394.3)),
#  (0.5, 4, 0.1, 94.0, 0.1893610417842865, (392000.0, 2054.0)),
#  (0.7, 1, 0.001, 96.5, 0.19287680387496947, (392000.0, 2366.8)),
#  (0.7, 1, 0.01, 94.54, 0.19160792827606202, (392000.0, 2050.7)),
#  (0.7, 1, 0.1, 22.02, 0.19379042983055114, (392000.0, 2000.0)),
#  (0.7, 2, 0.001, 96.22, 0.4130450189113617, (392000.0, 2453.5)),
#  (0.7, 2, 0.01, 95.08, 0.18250105977058412, (392000.0, 2104.6)),
#  (0.7, 2, 0.1, 69.0, 0.1921910524368286, (392000.0, 2000.0)),
#  (0.7, 4, 0.001, 98.08, 0.19290743470191957, (392000.0, 2786.5)),
#  (0.7, 4, 0.01, 96.4, 0.3138241350650787, (392000.0, 2276.5)),
#  (0.7, 4, 0.1, 91.54, 0.45781601071357725, (392000.0, 2006.9)),
#  (0.9, 1, 0.001, 96.28, 0.19173746705055236, (392000.0, 2344.0)),
#  (0.9, 1, 0.01, 93.06, 0.19347615242004396, (392000.0, 2023.7)),
#  (0.9, 1, 0.1, 11.8, 0.19421934485435485, (392000.0, 2000.0)),
#  (0.9, 2, 0.001, 95.88, 0.1915630578994751, (392000.0, 2555.7)),
#  (0.9, 2, 0.01, 83.22, 0.19278000593185424, (392000.0, 2001.8)),
#  (0.9, 2, 0.1, 22.52, 0.2283664047718048, (392000.0, 2000.0)),
#  (0.9, 4, 0.001, 97.18, 0.19516714215278624, (392000.0, 2687.0)),
#  (0.9, 4, 0.01, 82.82, 0.19168105125427246, (392000.0, 2038.8)),
#  (0.9, 4, 0.1, 70.06, 0.1931413471698761, (392000.0, 2000.0))]

# %%
list(filter(lambda r: r[3] > 90 and r[4] < 0.2 and r[5][1] < 2500, results))
# Out:
# [(0.1, 2, 0.1, 94.78, 0.18251324892044068, (392000.0, 2202.8)),
#  (0.1, 4, 0.1, 98.14, 0.19238696098327637, (392000.0, 2429.7)),
#  (0.3, 1, 0.01, 95.86, 0.19117312431335448, (392000.0, 2214.0)),
#  (0.3, 2, 0.01, 97.14, 0.19354044198989867, (392000.0, 2375.2)),
#  (0.3, 4, 0.1, 96.08, 0.19130685329437255, (392000.0, 2135.8)),
#  (0.5, 1, 0.01, 94.74, 0.1917216360569, (392000.0, 2075.3)),
#  (0.5, 2, 0.01, 95.62, 0.1923802375793457, (392000.0, 2186.6)),
#  (0.5, 4, 0.1, 94.0, 0.1893610417842865, (392000.0, 2054.0)),
#  (0.7, 1, 0.001, 96.5, 0.19287680387496947, (392000.0, 2366.8)),
#  (0.7, 1, 0.01, 94.54, 0.19160792827606202, (392000.0, 2050.7)),
#  (0.7, 2, 0.01, 95.08, 0.18250105977058412, (392000.0, 2104.6)),
#  (0.9, 1, 0.001, 96.28, 0.19173746705055236, (392000.0, 2344.0)),
#  (0.9, 1, 0.01, 93.06, 0.19347615242004396, (392000.0, 2023.7))]

# %%
eval_accuracy(student, testloader, quiet=False)
print(f"Latency: {student.get_avg_inference_time():.4}")
print(f"Transmission Size: {student.get_avg_transmission_sizes()} bytes")
student.clear_stats()
# Out:
# Accuracy: 88.96%
# Latency: 0.03368
# Transmission Size: (3136.0, 12.28) bytes

# %%
training_stage2(student, trainloader, quiet=False)
# Out:
# Epoch 1/10, Loss: 0.8937
# Epoch 2/10, Loss: 0.8107
# Epoch 3/10, Loss: 0.7671
# Epoch 4/10, Loss: 0.7392
# Epoch 5/10, Loss: 0.7226
# Epoch 6/10, Loss: 0.7041
# Epoch 7/10, Loss: 0.6974
# Epoch 8/10, Loss: 0.6831
# Epoch 9/10, Loss: 0.6712
# Epoch 10/10, Loss: 0.6638

# %%
eval_accuracy(student, testloader, quiet=False)
print(f"Latency: {student.get_avg_inference_time():.4}")
print(f"Transmission Size: {student.get_avg_transmission_sizes()} bytes")
student.clear_stats()
# Out:
# Accuracy: 83.78%
# Latency: 0.03239
# Transmission Size: (3136.0, 8.7584) bytes

# %%
torch.save(student, './models/MNIST_Complex_HECS.pt')
